# %% [markdown]
# ##### !/usr/bin/env python3
# ##### -*- coding: utf-8 -*-
# """
# Created on Fri May 11 01:36:39 2018
#
# @author: camkhanhdao
# """

# %%
import CleanData

# %%
# each data table
voltage = CleanData.ReadData(1).read_voltage()
humidity = CleanData.ReadData(2).read_voltage()
irradiance = CleanData.ReadData(3).read_irradiance()
# Out:
# b'Skipping line 19261: expected 6 fields, saw 7\nSkipping line 19268: expected 6 fields, saw 7\nSkipping line 19336: expected 6 fields, saw 7\nSkipping line 19351: expected 6 fields, saw 7\nSkipping line 19358: expected 6 fields, saw 7\nSkipping line 19463: expected 6 fields, saw 7\nSkipping line 19488: expected 6 fields, saw 7\nSkipping line 19495: expected 6 fields, saw 7\nSkipping line 19510: expected 6 fields, saw 8\nSkipping line 19533: expected 6 fields, saw 7\nSkipping line 19548: expected 6 fields, saw 7\nSkipping line 19578: expected 6 fields, saw 7\nSkipping line 19585: expected 6 fields, saw 7\nSkipping line 19674: expected 6 fields, saw 7\nSkipping line 19689: expected 6 fields, saw 7\nSkipping line 19750: expected 6 fields, saw 8\nSkipping line 19818: expected 6 fields, saw 7\nSkipping line 19847: expected 6 fields, saw 7\nSkipping line 19900: expected 6 fields, saw 7\nSkipping line 19915: expected 6 fields, saw 7\nSkipping line 19937: expected 6 fields, saw 7\nSkipping 
# ...

# %%
# full data table
df = CleanData.main_merge()
# Out:
# /Users/camkhanhdao/.conda/envs/LIWEfacades/lib/python3.7/site-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import PlotData

# %%
# scatter plot 
#PlotData(var='T',index=3,types=2).scatter_plot()

#correlation plot
PlotData.PlotData(types=1).correlation_plot()

#violin plot
PlotData.PlotData(types=3).violin_plot()

# %%
import Regression

# %%
#Regression model
Regression.Regression('v2').regression()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     v2   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                 7.057e+05
# Date:                Mon, 15 Jul 2019   Prob (F-statistic):               0.00
# Time:                        04:03:40   Log-Likelihood:            -8.3095e+05
# No. Observations:              475098   AIC:                         1.662e+06
# Df Residuals:                  475094   BIC:                         1.662e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.9690      0.016    504.244      0.000       7.938       8.000
# ...
